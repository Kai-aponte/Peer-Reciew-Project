# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Kayla Aponte__
# Data Scientist

# %% [markdown]
# _I am interested in data science because I embodied the core value of continuous improvement and data science gives me that opportunity to provide this insight for companies. I am currently in the healthcare field and am very excited for my transition._

# %% [markdown]
# ### Cell 5 should add 1 + 1:  2

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# |Data|Science|Project|
# |----|:-----:|------:|
# |Mark|Down   |Table  |
#
# ```python
# s = "Python syntax highlighting"
# print s
# ```
#
# [What is data science](https://www/google.com)
